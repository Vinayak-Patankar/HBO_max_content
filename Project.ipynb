# %% [markdown]
# # Project

# %%
import pandas as pd

# %% [markdown]
# # cleaning

# %%
df=pd.read_csv("D:\python\Pandas\Project\HBO_MAX_Content.csv")
df.duplicated().sum()#there are 12 duplicates
df.drop_duplicates(inplace=True)#deleting duplicates
df
# Out:
#                                                   title type  year
# 0                                       Game of Thrones   TV  2011  \
# 1                                        Rick and Morty   TV  2013
# 2     The Lord of the Rings: The Fellowship of the Ring  NaN  2001
# 3                                            Fight Club  NaN  1999
# 4                 The Lord of the Rings: The Two Towers  NaN  2002
# ...                                                 ...  ...   ...
# 2082                          Mystery Signal From Space  NaN  2018
# 2083                               The Norwegian Fjords  NaN  2018
# 2084                          Mandrake Telefilm: Part 1  NaN  2013
# 2085                                   What Animals See  NaN  2018
# 2086                        Top Science Stories of 2019  NaN  2019
#
#            rating  imdb_score  rotten_score     decade imdb_bucket
# 0         R/TV-MA         9.3          89.0  2010-2019   9.01-9.50  \
# ...

# %%
df.loc[df['year'].idxmax()].to_string()#Latest show released
# Out:
# 'title                                   The Outsider\ntype                                              TV\nyear                                            2020\nrating                                       R/TV-MA\nimdb_score                                       7.9\nrotten_score                                    82.0\ndecade                                     2020-2029\nimdb_bucket                                7.51-8.00\ngenres_Action_Adventure                            0\ngenres_Animation                                   0\ngenres_Anime                                       0\ngenres_Biography                                   0\ngenres_Children                                    0\ngenres_Comedy                                      0\ngenres_Crime                                       1\ngenres_Cult                                        0\ngenres_Documentary                                 0\ngenres_Drama                                       1\ngenres_Family            
# ...

# %% [markdown]
# # Latest show released

# %%
df.loc[df['year'].idxmax()].to_string()
# Out:
# 'title                                   The Outsider\ntype                                              TV\nyear                                            2020\nrating                                       R/TV-MA\nimdb_score                                       7.9\nrotten_score                                    82.0\ndecade                                     2020-2029\nimdb_bucket                                7.51-8.00\ngenres_Action_Adventure                            0\ngenres_Animation                                   0\ngenres_Anime                                       0\ngenres_Biography                                   0\ngenres_Children                                    0\ngenres_Comedy                                      0\ngenres_Crime                                       1\ngenres_Cult                                        0\ngenres_Documentary                                 0\ngenres_Drama                                       1\ngenres_Family            
# ...

# %% [markdown]
# # oldest show released

# %%
df.loc[df['year'].idxmin()].to_string()
# Out:
# 'title                                   A Night in the Show\ntype                                                    NaN\nyear                                                   1915\nrating                                                  NaN\nimdb_score                                              6.5\nrotten_score                                            NaN\ndecade                                            1910-1919\nimdb_bucket                                       6.01-7.00\ngenres_Action_Adventure                                   0\ngenres_Animation                                          0\ngenres_Anime                                              0\ngenres_Biography                                          0\ngenres_Children                                           0\ngenres_Comedy                                             1\ngenres_Crime                                              0\ngenres_Cult                                               0\ngenres_Documentary   
# ...

# %% [markdown]
# # Types of rating given to movie

# %%
df['rating'].unique()
# Out:
# array(['R/TV-MA', 'PG-13/TV-14', 'PG/TV-PG', nan, 'G/TV-G'], dtype=object)

# %% [markdown]
# # Rating

# %% [markdown]
# # Info about all 'R/TV-MA' movie

# %%
df.loc[df['rating']=='R/TV-MA',:]
# Out:
#                       title type  year   rating  imdb_score  rotten_score  \
# 0           Game of Thrones   TV  2011  R/TV-MA         9.3          89.0
# 1            Rick and Morty   TV  2013  R/TV-MA         9.2          94.0
# 3                Fight Club  NaN  1999  R/TV-MA         8.8          79.0
# 7                     Alien  NaN  1979  R/TV-MA         8.4          94.0
# 8                 Chernobyl   TV  2019  R/TV-MA         9.4          96.0
# ...                     ...  ...   ...      ...         ...           ...
# 1977  Cold Around the Heart  NaN  1997  R/TV-MA         5.1           NaN
# 1984           Episode #1.1  NaN  2006  R/TV-MA         6.8           NaN
# 1985           Episode #1.1  NaN  2006  R/TV-MA         6.8           NaN
# 1994       Positively Naked  NaN  2005  R/TV-MA         6.3           NaN
# 2032            The Getaway  NaN  2020  R/TV-MA         NaN           NaN
#
#          decade imdb_bucket  genres_Action_Adventure  genres_Animation  ...  \
# ...

# %% [markdown]
# # Info about all 'PG-13/TV-14' movie

# %%
df.loc[df['rating']=='PG-13/TV-14',:]#info about all 'R/TV-MA' movie
# Out:
#                                                   title type  year  \
# 2     The Lord of the Rings: The Fellowship of the Ring  NaN  2001
# 4                 The Lord of the Rings: The Two Towers  NaN  2002
# 5         The Lord of the Rings: The Return of the King  NaN  2003
# 13                                              Friends   TV  1994
# 15                         Once Upon a Time in the West  NaN  1968
# ...                                                 ...  ...   ...
# 1953  In Tahrir Square: 18 Days of Egypt's Unfinishe...  NaN  2012
# 1958   No Contract, No Cookies: The Stella D'Oro Strike  NaN  2010
# 1963                 Studs Terkel: Listening to America  NaN  2009
# 1982                                           Odd Jobs  NaN  1986
# 2015                                          Full Beat  NaN  2018
#
#            rating  imdb_score  rotten_score     decade imdb_bucket  \
# 2     PG-13/TV-14         8.8          91.0  2000-2009   8.51-9.00
# ...

# %% [markdown]
# # info about all 'PG/TV-PG' movie

# %%
df.loc[df['rating']=='PG/TV-PG',:]
# Out:
#                                                   title type  year    rating  \
# 6                                         Spirited Away  NaN  2001  PG/TV-PG
# 19                                           Casablanca  NaN  1942  PG/TV-PG
# 24                                                 Jaws  NaN  1975  PG/TV-PG
# 35                                   My Neighbor Totoro  NaN  1988  PG/TV-PG
# 41             Harry Potter and the Prisoner of Azkaban  NaN  2004  PG/TV-PG
# ...                                                 ...  ...   ...       ...
# 2018                          Ebola: The Doctors' Story  NaN  2016  PG/TV-PG
# 2025                                        Habla Texas  NaN  2011  PG/TV-PG
# 2028  RX: Early Detection - A Cancer Journey with Sa...  NaN  2018  PG/TV-PG
# 2036                                       Habla y vota  NaN  2016  PG/TV-PG
# 2039                           The Adventures of Jinbao  NaN  2012  PG/TV-PG
#
# ...

# %% [markdown]
# # info about all 'G/TV-G' movie

# %%
df.loc[df['rating']=='G/TV-G',:]
# Out:
#                                      title type  year  rating  imdb_score  \
# 22                   2001: A Space Odyssey  NaN  1968  G/TV-G         8.3
# 53                        The Wizard of Oz  NaN  1939  G/TV-G         8.0
# 59                     Singin' in the Rain  NaN  1952  G/TV-G         8.3
# 63                            Modern Times  NaN  1936  G/TV-G         8.5
# 66                      Gone with the Wind  NaN  1939  G/TV-G         8.1
# ...                                    ...  ...   ...     ...         ...
# 1990      Alpha and Omega: The Big Fureeze  NaN  2016  G/TV-G         4.8
# 1997                 Journey Into Dyslexia  NaN  2011  G/TV-G         6.5
# 2008                   Portraits of a Lady  NaN  2008  G/TV-G         5.6
# 2027  I Can Be President: A Kid's-Eye View  NaN  2011  G/TV-G         6.4
# 2034               Search for Second Earth   TV  2018  G/TV-G         7.8
#
#       rotten_score     decade imdb_bucket  genres_Action_Adventure  \
# ...

# %%
df.groupby('rating').min()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10076\1163554342.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   df.groupby('rating').min()
#                                 title  year  imdb_score  rotten_score  \
# rating
# G/TV-G               16 Days of Glory  1916         4.1          12.0
# PG-13/TV-14           12th & Delaware  1929         2.2           3.0
# PG/TV-PG     ...And God Created Woman  1928         1.7           4.0
# R/TV-MA         12 Rounds 3: Lockdown  1962         2.3           5.0
#
#                 decade  genres_Action_Adventure  genres_Animation  \
# rating
# G/TV-G       1910-1919                        0                 0
# PG-13/TV-14  1920-1929                        0                 0
# PG/TV-PG     1920-1929                        0                 0
# ...

# %% [markdown]
# # Imdb score

# %% [markdown]
# # Highest imdb rating movie

# %%
df.loc[df['imdb_score'].idxmax()]
# Out:
# title                           El Astronauta
# type                                      NaN
# year                                     2018
# rating                               PG/TV-PG
# imdb_score                                9.9
#                                     ...
# platforms_tnt                               0
# platforms_trutv_tveverywhere                0
# platforms_urbanmoviechannel                 0
# platforms_velocity_go                       0
# platforms_watch_tcm                         0
# Name: 1592, Length: 75, dtype: object

# %% [markdown]
# # Lowest imdb rating movie

# %%
df.loc[df['imdb_score'].idxmin()]
# Out:
# title                           Justin Bieber's Believe
# type                                                NaN
# year                                               2013
# rating                                         PG/TV-PG
# imdb_score                                          1.7
#                                          ...
# platforms_tnt                                         0
# platforms_trutv_tveverywhere                          0
# platforms_urbanmoviechannel                           0
# platforms_velocity_go                                 0
# platforms_watch_tcm                                   0
# Name: 1467, Length: 75, dtype: object

# %% [markdown]
# # more than 8 imdb_score movies

# %%
df.loc[df.imdb_score>8]
# Out:
#                                                   title type  year  \
# 1306                               The Electric Company   TV  1971
# 1094  At the Heart of Gold: Inside the USA Gymnastic...  NaN  2019
# 1453                                          Fugitives   TV  2011
# 397                          Paradise Lost 3: Purgatory  NaN  2011
# 96                                       Cool Hand Luke  NaN  1967
# ...                                                 ...  ...   ...
# 0                                       Game of Thrones   TV  2011
# 23                                     Band of Brothers   TV  2001
# 8                                             Chernobyl   TV  2019
# 1669                                             Wonder  NaN  2019
# 1592                                      El Astronauta  NaN  2018
#
#            rating  imdb_score  rotten_score     decade imdb_bucket  \
# 1306       G/TV-G         8.1           NaN  1970-1979   8.01-8.50
# ...

# %% [markdown]
# # less than 5 imdb_score movies

# %%
df.loc[df.imdb_score<5].sort_values("imdb_score",ascending=False)
# Out:
#                          title type  year       rating  imdb_score  \
# 1639              Gone Fishin'  NaN  1997     PG/TV-PG         4.9
# 927            The Flintstones  NaN  1994     PG/TV-PG         4.9
# 928            The Flintstones  NaN  1994     PG/TV-PG         4.9
# 1419              Black Knight  NaN  2001  PG-13/TV-14         4.9
# 1765         Mighty Magiswords   TV  2015     PG/TV-PG         4.9
# ...                        ...  ...   ...          ...         ...
# 805                     Ben 10   TV  2016     PG/TV-PG         2.5
# 1976                      Anna  NaN  2017      R/TV-MA         2.3
# 1794                   Glitter  NaN  2001  PG-13/TV-14         2.2
# 2039  The Adventures of Jinbao  NaN  2012     PG/TV-PG         1.8
# 1467   Justin Bieber's Believe  NaN  2013     PG/TV-PG         1.7
#
#       rotten_score     decade imdb_bucket  genres_Action_Adventure  \
# 1639           4.0  1990-1999      0-5.00                        0
# ...

# %% [markdown]
# # total no.of all column for range of rating.

# %%
df.groupby('imdb_bucket').count()
# Out:
#              title  type  year  rating  imdb_score  rotten_score  decade
# imdb_bucket
# 0-5.00         103    14   103      97         103            51     103  \
# 5.01-6.00      276    23   276     234         276           192     276
# 6.01-7.00      575    53   575     447         575           399     575
# 7.01-7.50      416    70   416     307         416           276     416
# 7.51-8.00      381    76   381     248         381           267     381
# 8.01-8.50      204    82   204     145         204           137     204
# 8.51-9.00       46    32    46      37          46            24      46
# 9.01-9.50       10     8    10       8          10             7      10
# 9.51-10          2     0     2       1           2             0       2
#
#              genres_Action_Adventure  genres_Animation  genres_Anime  ...
# imdb_bucket                                                           ...
# 0-5.00                           103               103           103  ...  \
# ...

# %% [markdown]
# # Rotten_score

# %% [markdown]
# # Highest rotten_score movie

# %%
df.loc[df['rotten_score'].idxmax()]
# Out:
# title                           Seven Samurai
# type                                      NaN
# year                                     1954
# rating                                    NaN
# imdb_score                                8.6
#                                     ...
# platforms_tnt                               0
# platforms_trutv_tveverywhere                0
# platforms_urbanmoviechannel                 0
# platforms_velocity_go                       0
# platforms_watch_tcm                         0
# Name: 18, Length: 75, dtype: object

# %% [markdown]
# # Highest rotten_score movie

# %%
df.loc[df['rotten_score'].idxmin()]
# Out:
# title                           Down to You
# type                                    NaN
# year                                   2000
# rating                          PG-13/TV-14
# imdb_score                              5.0
#                                    ...
# platforms_tnt                             0
# platforms_trutv_tveverywhere              0
# platforms_urbanmoviechannel               0
# platforms_velocity_go                     0
# platforms_watch_tcm                       0
# Name: 1517, Length: 75, dtype: object

# %% [markdown]
# # more than 50 rotten_score movies

# %%
df.loc[df.rotten_score>50]
# Out:
#                                                   title type  year  \
# 0                                       Game of Thrones   TV  2011
# 1                                        Rick and Morty   TV  2013
# 2     The Lord of the Rings: The Fellowship of the Ring  NaN  2001
# 3                                            Fight Club  NaN  1999
# 4                 The Lord of the Rings: The Two Towers  NaN  2002
# ...                                                 ...  ...   ...
# 1741                                       Being Serena   TV  2018
# 1771                Ali & Cavett: The Tale of the Tapes  NaN  2018
# 1801                                   Song of Parkland  NaN  2019
# 1804                                            The End  NaN  2004
# 1850                                    Angel Rodriguez  NaN  2005
#
#            rating  imdb_score  rotten_score     decade imdb_bucket  \
# 0         R/TV-MA         9.3          89.0  2010-2019   9.01-9.50
# ...

# %% [markdown]
# # less than 5 rotten_score movies

# %%
df.loc[df.rotten_score<50].sort_values("rotten_score",ascending=False
# Out:
#                    title type  year       rating  imdb_score  rotten_score  \
# 711      We Are Marshall  NaN  2006     PG/TV-PG         7.1          49.0
# 1253    Battle for Terra  NaN  2007     PG/TV-PG         6.5          49.0
# 816               Scoob!  NaN  2020     PG/TV-PG         5.7          49.0
# 1117            Freeheld  NaN  2015  PG-13/TV-14         6.6          49.0
# 991          Hummingbird  NaN  2013      R/TV-MA         6.2          49.0
# ...                  ...  ...   ...          ...         ...           ...
# 1392            Mobsters  NaN  1991      R/TV-MA         6.0           6.0
# 1742             College  NaN  2008      R/TV-MA         4.6           5.0
# 1773  Witless Protection  NaN  2008  PG-13/TV-14         3.3           4.0
# 1639        Gone Fishin'  NaN  1997     PG/TV-PG         4.9           4.0
# 1517         Down to You  NaN  2000  PG-13/TV-14         5.0           3.0
#
# ...

# %% [markdown]
# # Decade

# %% [raw]
# #for spliting decade

# %%
df[["From","To"]]=df['decade'].str.split('-',expand=True)

# %%
df[["From","To"]]=df[["From","To"]].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2086
# Data columns (total 77 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   title                                 2075 non-null   object
#  1   type                                  373 non-null    object
#  2   year                                  2075 non-null   int64
#  3   rating                                1528 non-null   object
#  4   imdb_score                            2013 non-null   float64
#  5   rotten_score                          1353 non-null   float64
#  6   decade                                2075 non-null   object
#  7   imdb_bucket                           2013 non-null   object
#  8   genres_Action_Adventure               2075 non-null   int64
#  9   genres_Animation                      2075 non-null   int64
#  10  genres_Anime                          2075 non-null   int64
# ...

# %% [markdown]
# # 19's shows

# %%
df.loc[(df.From)<2000]
# Out:
#                                                 title type  year   rating  \
# 3                                          Fight Club  NaN  1999  R/TV-MA
# 7                                               Alien  NaN  1979  R/TV-MA
# 9                                   Good Will Hunting  NaN  1997  R/TV-MA
# 10                                           Die Hard  NaN  1988  R/TV-MA
# 12                                             Aliens  NaN  1986  R/TV-MA
# ...                                               ...  ...   ...      ...
# 2002  Nagano ’98 Olympics: Stories of Honor and Glory  NaN  1998      NaN
# 2006          IX Olympic Winter Games, Innsbruck 1964  NaN  1964      NaN
# 2007                     The IX Olympiad in Amsterdam  NaN  1928      NaN
# 2019                                Earthday Birthday  NaN  1990      NaN
# 2069                                         Pen Pals  NaN  1988      NaN
#
#       imdb_score  rotten_score     decade imdb_bucket  \
# ...

# %%
df.loc[(df.From)<2000].shape[0]#shape[0] is usually use for calculate total,which is satisfying to condition.
# Out:
# 793

# %% [markdown]
# # 20's shows

# %%
df.loc[(df.From)>2000]#20's shows
# Out:
#                                              title type  year       rating  \
# 0                                  Game of Thrones   TV  2011      R/TV-MA
# 1                                   Rick and Morty   TV  2013      R/TV-MA
# 8                                        Chernobyl   TV  2019      R/TV-MA
# 11                                           Joker  NaN  2019      R/TV-MA
# 17    Harry Potter and the Deathly Hallows: Part 2  NaN  2011  PG-13/TV-14
# ...                                            ...  ...   ...          ...
# 2082                     Mystery Signal From Space  NaN  2018          NaN
# 2083                          The Norwegian Fjords  NaN  2018          NaN
# 2084                     Mandrake Telefilm: Part 1  NaN  2013          NaN
# 2085                              What Animals See  NaN  2018          NaN
# 2086                   Top Science Stories of 2019  NaN  2019          NaN
#
#       imdb_score  rotten_score     decade imdb_bucket  \
# ...

# %%
df.loc[(df.From)>2000].shape[0]
# Out:
# 846

# %% [markdown]
# # genres_Action_Adventure

# %%
df[df['genres_Action_Adventure']==1]#all genres_Action_Adventure movies
# Out:
#                                                   title type  year  \
# 0                                       Game of Thrones   TV  2011
# 1                                        Rick and Morty   TV  2013
# 2     The Lord of the Rings: The Fellowship of the Ring  NaN  2001
# 4                 The Lord of the Rings: The Two Towers  NaN  2002
# 5         The Lord of the Rings: The Return of the King  NaN  2003
# ...                                                 ...  ...   ...
# 1971                            Wings: Sky Force Heroes  NaN  2014
# 1989                                   Elephant Kingdom  NaN  2016
# 1990                   Alpha and Omega: The Big Fureeze  NaN  2016
# 2039                           The Adventures of Jinbao  NaN  2012
# 2058                                        My Treasure  NaN  2017
#
#            rating  imdb_score  rotten_score     decade imdb_bucket  \
# 0         R/TV-MA         9.3          89.0  2010-2019   9.01-9.50
# ...

# %%
df[df['genres_Action_Adventure']==1].shape[0]#sum of total genres_Action_Adventure movies
# Out:
# 486

# %%
df.column
# Out:
# Index(['title', 'type', 'year', 'rating', 'imdb_score', 'rotten_score',
#        'decade', 'imdb_bucket', 'genres_Action_Adventure', 'genres_Animation',
#        'genres_Anime', 'genres_Biography', 'genres_Children', 'genres_Comedy',
#        'genres_Crime', 'genres_Cult', 'genres_Documentary', 'genres_Drama',
#        'genres_Family', 'genres_Fantasy', 'genres_Food', 'genres_Game Show',
#        'genres_History', 'genres_Home_Garden', 'genres_Horror',
#        'genres_Independent', 'genres_LGBTQ', 'genres_Musical',
#        'genres_Mystery', 'genres_Reality', 'genres_Romance',
#        'genres_Science_Fiction', 'genres_Sport', 'genres_Stand_up_Talk',
#        'genres_Thriller', 'genres_Travel', 'platforms_acorntv',
#        'platforms_adult_swim_tveverywhere', 'platforms_amazon_prime',
#        'platforms_amc', 'platforms_amc_premiere', 'platforms_bbc_america_tve',
#        'platforms_britbox', 'platforms_cartoon_network',
#        'platforms_cbs_all_access', 'platforms_cinemax',
# ...

# %% [markdown]
# # genres_Animation

# %%
df[df['genres_Animation']==1]#all genres_Animation
# Out:
#                                  title type  year       rating  imdb_score
# 1                       Rick and Morty   TV  2013      R/TV-MA         9.2  \
# 6                        Spirited Away  NaN  2001     PG/TV-PG         8.6
# 31                   Princess Mononoke  NaN  1997  PG-13/TV-14         8.4
# 35                  My Neighbor Totoro  NaN  1988     PG/TV-PG         8.2
# 37                        Wonder Woman  NaN  2017  PG-13/TV-14         7.4
# ...                                ...  ...   ...          ...         ...
# 1989                  Elephant Kingdom  NaN  2016     PG/TV-PG         4.0
# 1990  Alpha and Omega: The Big Fureeze  NaN  2016       G/TV-G         4.8
# 2019                 Earthday Birthday  NaN  1990          NaN         6.0
# 2039          The Adventures of Jinbao  NaN  2012     PG/TV-PG         1.8
# 2045                    Fantasmagorias   TV  2017          NaN         NaN
#
#       rotten_score     decade imdb_bucket  genres_Action_Adventure
# ...

# %% [markdown]
# #sum of total genres_Animation

# %%
df[df['genres_Animation']==1].shape[0]
# Out:
# 189

# %% [markdown]
# # genres_Anime

# %%
df[df['genres_Anime']==1]#all genres_Anime
# Out:
#                                                   title type  year
# 6                                         Spirited Away  NaN  2001  \
# 31                                    Princess Mononoke  NaN  1997
# 35                                   My Neighbor Totoro  NaN  1988
# 47                                 Howl's Moving Castle  NaN  2004
# 52                     Fullmetal Alchemist: Brotherhood   TV  2009
# 105                                   Castle in the Sky  NaN  1986
# 119                  Nausicaä of the Valley of the Wind  NaN  1984
# 143                                               Ponyo  NaN  2008
# 178                                          Death Note   TV  2006
# 197                                Whisper of the Heart  NaN  1995
# 205                                         Porco Rosso  NaN  1992
# 210                     The Tale of the Princess Kaguya  NaN  2013
# 221                        The Secret World of Arrietty  NaN  2010
# ...

# %% [markdown]
# #sum of total genres_Anime

# %%
df[df['genres_Anime']==1].shape[0]
# Out:
# 36

# %% [markdown]
# # genres_Biography

# %%
df[df['genres_Biography']==1]#all genres_Biography
# Out:
#                                                   title type  year
# 20                                       Ford v Ferrari  NaN  2019  \
# 40                                           Braveheart  NaN  1995
# 48                                                 Rush  NaN  2013
# 60                                       BlacKkKlansman  NaN  2018
# 91                                    Bohemian Rhapsody  NaN  2018
# ...                                                 ...  ...   ...
# 1854                                The Battle of Amfar  NaN  2013
# 1897  Thank You, Mr. President: Helen Thomas at the ...  NaN  2008
# 1919         Dark Light: The Art Of Blind Photographers  NaN  2009
# 1963                 Studs Terkel: Listening to America  NaN  2009
# 2021          Silencing the Song: An Afghan Fallen Star  NaN  2011
#
#            rating  imdb_score  rotten_score     decade imdb_bucket
# 20    PG-13/TV-14         8.1          92.0  2010-2019   8.01-8.50  \
# ...

# %% [markdown]
# #sum of total genres_Biography

# %%
df[df['genres_Biography']==1].shape[0]
# Out:
# 136

# %% [markdown]
# # genres_Children

# %%
df[df['genres_Children']==1]#all genres_Children
# Out:
#                                                 title type  year       rating
# 109                                    Adventure Time   TV  2010     PG/TV-PG  \
# 137                                        Home Alone  NaN  1990     PG/TV-PG
# 339                                               Rio  NaN  2011       G/TV-G
# 413                                       Teen Titans   TV  2003     PG/TV-PG
# 549                    Home Alone 2: Lost in New York  NaN  1992     PG/TV-PG
# 577                                     Tom and Jerry   TV  1940       G/TV-G
# 579                                            Storks  NaN  2016     PG/TV-PG
# 584                                      Samurai Jack   TV  2001  PG-13/TV-14
# 590                                   Steven Universe   TV  2013     PG/TV-PG
# 693                      The Amazing World of Gumball   TV  2011     PG/TV-PG
# 722                                     Sesame Street   TV  1969       G/TV-G
# ...

# %% [markdown]
# #sum of total genres_Children

# %%
df[df['genres_Children']==1].shape[0]
# Out:
# 58

# %% [markdown]
# # genres_Comedy

# %%
df[df['genres_Comedy']==1]#all genres_Comedy

# %% [markdown]
# #sum of total genres_Comedy

# %%
df[df['genres_Comedy']==1].shape[0]

# %% [markdown]
# # genres_Crime

# %%
df[df['genres_Crime']==1]#all genres_Crime
# Out:
#                                title type  year       rating  imdb_score
# 11                             Joker  NaN  2019      R/TV-MA         8.5  \
# 16                          The Wire   TV  2002      R/TV-MA         9.3
# 30                      The Sopranos   TV  1999      R/TV-MA         9.2
# 33               Requiem for a Dream  NaN  2000      R/TV-MA         8.3
# 44                    True Detective   TV  2014      R/TV-MA         9.0
# ...                              ...  ...   ...          ...         ...
# 1910               Shanghai Surprise  NaN  1986  PG-13/TV-14         3.2
# 1928  The Return of Bulldog Drummond  NaN  1934          NaN         5.6
# 1977           Cold Around the Heart  NaN  1997      R/TV-MA         5.1
# 2031               Mandrake Telefilm  NaN  2013          NaN         5.4
# 2032                     The Getaway  NaN  2020      R/TV-MA         NaN
#
#       rotten_score     decade imdb_bucket  genres_Action_Adventure
# ...

# %% [markdown]
# #sum of total genres_Crime

# %%
df[df['genres_Crime']==1].shape[0]
# Out:
# 296

# %% [markdown]
# # genres_Cult

# %%
df[df['genres_Cult']==1]#all genres_Cult
# Out:
#                                                   title type  year
# 3                                            Fight Club  NaN  1999  \
# 7                                                 Alien  NaN  1979
# 22                                2001: A Space Odyssey  NaN  1968
# 72                                            In Bruges  NaN  2008
# 110                            Night of the Living Dead  NaN  1968
# 166                                 A Fish Called Wanda  NaN  1988
# 167                                 Glengarry Glen Ross  NaN  1992
# 187                                    Harold and Maude  NaN  1971
# 227   Going Clear: Scientology and the Prison of Belief  NaN  2015
# 235                      An American Werewolf in London  NaN  1981
# 260                                         Deliverance  NaN  1972
# 278                                        Withnail & I  NaN  1987
# 279                           Hedwig and the Angry Inch  NaN  2001
# ...

# %% [markdown]
# #sum of total genres_Cult

# %%
df[df['genres_Cult']==1.shape[0]
# Out:
#                                                   title type  year
# 3                                            Fight Club  NaN  1999  \
# 7                                                 Alien  NaN  1979
# 22                                2001: A Space Odyssey  NaN  1968
# 72                                            In Bruges  NaN  2008
# 110                            Night of the Living Dead  NaN  1968
# 166                                 A Fish Called Wanda  NaN  1988
# 167                                 Glengarry Glen Ross  NaN  1992
# 187                                    Harold and Maude  NaN  1971
# 227   Going Clear: Scientology and the Prison of Belief  NaN  2015
# 235                      An American Werewolf in London  NaN  1981
# 260                                         Deliverance  NaN  1972
# 278                                        Withnail & I  NaN  1987
# 279                           Hedwig and the Angry Inch  NaN  2001
# ...

# %% [markdown]
# # genres_Documentary

# %%
df[df['genres_Documentary']==1]#all genres_Documentary
# Out:
#                                                   title type  year
# 3                                            Fight Club  NaN  1999  \
# 7                                                 Alien  NaN  1979
# 22                                2001: A Space Odyssey  NaN  1968
# 72                                            In Bruges  NaN  2008
# 110                            Night of the Living Dead  NaN  1968
# 166                                 A Fish Called Wanda  NaN  1988
# 167                                 Glengarry Glen Ross  NaN  1992
# 187                                    Harold and Maude  NaN  1971
# 227   Going Clear: Scientology and the Prison of Belief  NaN  2015
# 235                      An American Werewolf in London  NaN  1981
# 260                                         Deliverance  NaN  1972
# 278                                        Withnail & I  NaN  1987
# 279                           Hedwig and the Angry Inch  NaN  2001
# ...

# %%
#sum of total genres_Documentary

# %%
df[df['genres_Documentary']==1.shape[0]

# %% [markdown]
# # genres_Drama

# %%
#all genres_Drama

df[df['genres_Drama']==1]

# %%
#sum of total genres_Drama

df[df['genres_Drama']==1.shape[0]

# %% [markdown]
# # genres_Family

# %%
#all genres_Family

df[df['genres_Family']==1]

# %%
#sum of total genres_Family

df[df['genres_Family']==1.shape[0]

# %% [markdown]
# # genres_Fantasy

# %%
#all genres_Fantasy

df[df['genres_Fantasy']==1]

# %%
#sum of total genres_Fantasy

df[df['genres_Fantasy']==1.shape[0]

# %% [markdown]
# # genres_Food

# %%
#all genres_Food

df[df['genres_Food']==1]

# %%
#sum of total genres_Food

df[df['genres_Food']==1.shape[0]

# %% [markdown]
# # genres_Game Show

# %%
#all genres_Game Show

df[df['genres_Game Show']==1]

# %%
#sum of total genres_Game Show

df[df['genres_Game Show']==1.shape[0]

# %% [markdown]
# # genres_History

# %%
#all genres_History

df[df['genres_History']==1]

# %%
#sum of total genres_History

df[df['genres_History']==1.shape[0]

# %% [markdown]
# # genres_Home_Garden

# %%
#all genres_Home_Garden

df[df['genres_Home_Garden']==1]

# %%
#sum of total genres_Home_Garden

df[df['genres_Home_Garden']==1.shape[0]

# %% [markdown]
# # genres_Horror

# %%
#all genres_Horror

df[df['genres_Home_Garden']==1]

# %%
#sum of total genres_Horror

df[df['genres_Home_Garden']==1.shape[0]

# %% [markdown]
# # genres_Independent

# %%
#all genres_Independent

df[df['genres_Independent']==1]

# %%
#sum of total genres_Independent

df[df['genres_Independent']==1.shape[0]

# %% [markdown]
# # genres_LGBTQ

# %%
#all genres_LGBTQ

df[df['genres_LGBTQ']==1]

# %%
#sum of total genres_LGBTQ

df[df['genres_LGBTQ']==1.shape[0]

# %% [markdown]
# # genres_Musical

# %%
#all genres_Musical

df[df['genres_Musical']==1]

# %%
#sum of total genres_Musical

df[df['genres_Musical']==1.shape[0]

# %% [markdown]
# # genres_Mystery

# %%
#all genres_Mystery

df[df['genres_Mystery']==1]

# %%
#sum of total genres_Mystery

df[df['genres_Mystery']==1.shape[0]

# %% [markdown]
# # genres_Reality

# %%
#all genres_Reality

df[df['genres_Reality']==1]

# %%
#sum of total genres_Reality

df[df['genres_Reality']==1.shape[0]

# %% [markdown]
# # genres_Romance

# %%
#all genres_Romance

df[df['genres_Romance']==1]

# %%
#all genres_Romance

df[df['genres_Romance']==1]

# %% [markdown]
# # genres_Science_Fiction

# %%
#all genres_Science_Fiction

df[df['genres_Science_Fiction']==1]

# %%
#all genres_Science_Fiction

df[df['genres_Science_Fiction']==1]

# %% [markdown]
# # genres_Sport

# %%
#all genres_Sport

df[df['genres_Sport']==1]

# %%
#all genres_Sport

df[df['genres_Sport']==1]

# %% [markdown]
# # genres_Stand_up_Talk

# %%
#all genres_Stand_up_Talk

df[df['genres_Stand_up_Talk']==1]

# %%
#all genres_Stand_up_Talk

df[df['genres_Stand_up_Talk']==1]

# %% [markdown]
# # genres_Thriller

# %%
#all genres_Thriller

df[df['genres_Thriller']==1]

# %%
#all genres_Thriller

df[df['genres_Thriller']==1]

# %% [markdown]
# # genres_Travel

# %%
#all genres_Travel

df[df['genres_Travel']==1]

# %%
#all genres_Travel

df[df['genres_Travel']==1]

# %%
df.columns
# Out:
# Index(['title', 'type', 'year', 'rating', 'imdb_score', 'rotten_score',
#        'decade', 'imdb_bucket', 'genres_Action_Adventure', 'genres_Animation',
#        'genres_Anime', 'genres_Biography', 'genres_Children', 'genres_Comedy',
#        'genres_Crime', 'genres_Cult', 'genres_Documentary', 'genres_Drama',
#        'genres_Family', 'genres_Fantasy', 'genres_Food', 'genres_Game Show',
#        'genres_History', 'genres_Home_Garden', 'genres_Horror',
#        'genres_Independent', 'genres_LGBTQ', 'genres_Musical',
#        'genres_Mystery', 'genres_Reality', 'genres_Romance',
#        'genres_Science_Fiction', 'genres_Sport', 'genres_Stand_up_Talk',
#        'genres_Thriller', 'genres_Travel', 'platforms_acorntv',
#        'platforms_adult_swim_tveverywhere', 'platforms_amazon_prime',
#        'platforms_amc', 'platforms_amc_premiere', 'platforms_bbc_america_tve',
#        'platforms_britbox', 'platforms_cartoon_network',
#        'platforms_cbs_all_access', 'platforms_cinemax',
# ...

# %% [markdown]
# # Movies on platform release

# %%
df[df['platforms_acorntv']==1]['title']
# Out:
# 1316    Five Days
# Name: title, dtype: object

# %%
df[df['platforms_adult_swim_tveverywhere']==1]['title']
# Out:
# 1                   Rick and Morty
# 301                Hunter x Hunter
# 354                  The Boondocks
# 584                   Samurai Jack
# 617                    Home Movies
# 703                  Robot Chicken
# 783         Aqua Teen Hunger Force
# 911                  Metalocalypse
# 1153    Space Ghost Coast to Coast
# Name: title, dtype: object
